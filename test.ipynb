# %%
import numpy as np

# %%
# create condition rnadomization 

conditions = [
    {"control": 
        {"n": 2
        }
    }, 
    {"h2v_left": 
        {"n": 1
        }
    }, 
    {"h2v_right": 
        {"n": 1
         }
    }, 
    {"v2h_left": 
        {"n": 1
         }
    }, 
    {"v2h_rigth": 
        {"n": 1
        }
    }, 
]


trials_per_condition = 100

# %%
vals_side = np.repeat([0, -1], 1)
vals_disamb = np.repeat(["hor", "ver", None], 1)
timings = np.arange(2, 9, 1)

combinations = [(x, y, z) for x in vals_side for y in vals_disamb for z in timings]


np.random.shuffle(combinations)

combinations
# Out:
# [(np.int64(-1), 'ver', np.int64(6)),
#  (np.int64(-1), None, np.int64(8)),
#  (np.int64(-1), None, np.int64(5)),
#  (np.int64(0), 'ver', np.int64(2)),
#  (np.int64(-1), None, np.int64(4)),
#  (np.int64(-1), 'ver', np.int64(7)),
#  (np.int64(-1), None, np.int64(6)),
#  (np.int64(0), 'hor', np.int64(2)),
#  (np.int64(-1), None, np.int64(3)),
#  (np.int64(0), 'ver', np.int64(3)),
#  (np.int64(0), None, np.int64(6)),
#  (np.int64(0), 'ver', np.int64(7)),
#  (np.int64(-1), 'ver', np.int64(5)),
#  (np.int64(0), 'hor', np.int64(6)),
#  (np.int64(-1), None, np.int64(7)),
#  (np.int64(0), 'hor', np.int64(7)),
#  (np.int64(0), 'ver', np.int64(6)),
#  (np.int64(0), 'hor', np.int64(3)),
#  (np.int64(-1), None, np.int64(2)),
#  (np.int64(0), 'hor', np.int64(4)),
#  (np.int64(0), None, np.int64(8)),
#  (np.int64(0), None, np.int64(2)),
#  (np.int64(-1), 'ver', np.int64(2)),
#  (np.int64(0), 'hor', np.int64(5)),
#  (np.int64(0), 'hor', np.int64(8)),
#  (np.int64(-1), 'ver', np.int64(4)),
#  (np.int64(-1), 'ver', np.int64(3)),
#  (np.int64(-1), 'hor', np.int64(2)),
#  (np.int64(-1), 'hor', np.int64(3)),
#  (np.int64(0), None, np.int64(5)),
#  (np.int64(-1), 'hor', np.int64(5)),
#  (np.int64(0), 'ver', np.int64(5)),
#  (np.int64(-1), 'hor', np.int64(7)),
#  (np.int64(0), 'ver', np.int64(4)),
#  (np.int64(-1), 'hor', np.int64(8)),
#  (np.int64(0), 'ver', np.int64(8)),
#  (np.int64(0), None, np.int64(7)),
#  (np.int64(0), None, np.int64(4)),
#  (np.int64(-1), 'ver', np.int64(8)),
#  (np.int64(-1), 'hor', np.int64(4)),
#  (np.int64(0), None, np.int64(3)),
#  (np.int64(-1), 'hor', np.int64(6))]
